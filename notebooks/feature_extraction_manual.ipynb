# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

# --- CONFIGURACIÓN ---
# Asegúrate de que estas rutas coincidan con tu entorno
PROJECT_ROOT = Path("..").resolve()
DATA_DIR = PROJECT_ROOT / "data"
AAL3_TXT_PATH = DATA_DIR / "ROI_MNI_V7_vol.txt"
OUTPUT_CSV_PATH = DATA_DIR / "aal3_131_manual_network_order.csv"

# --- 1. DICCIONARIO MAESTRO DE CONSENSO (AAL3 -> YEO17) ---
# Clave: Inicio del nombre corto (nom_c) de AAL3.
# Valor: Tupla (ID_Red_Yeo, Nombre_Red_Yeo)
# Estrategia para CNN: Agrupar visual/motor al inicio, cognitivo al medio, subcortical al final.

YEO_MAPPING = {
    # --- VISUAL (Yeo 1 & 2) ---
    'V1': (2, 'Visual_Central'), 'Calcarine': (2, 'Visual_Central'),
    'O1': (1, 'Visual_Peripheral'), 'Occipital_Sup': (1, 'Visual_Peripheral'),
    'O2': (1, 'Visual_Peripheral'), 'Occipital_Mid': (1, 'Visual_Peripheral'),
    'O3': (1, 'Visual_Peripheral'), 'Occipital_Inf': (1, 'Visual_Peripheral'),
    'LING': (1, 'Visual_Peripheral'), 'Lingual': (1, 'Visual_Peripheral'),
    'Q': (1, 'Visual_Peripheral'), 'Cuneus': (1, 'Visual_Peripheral'),
    'FUSI': (1, 'Visual_Peripheral'), 'Fusiform': (1, 'Visual_Peripheral'),

    # --- SOMATOMOTOR (Yeo 3 & 4) ---
    'FA': (3, 'Somatomotor_A'), 'Precentral': (3, 'Somatomotor_A'), # Motor
    'PA': (3, 'Somatomotor_A'), 'Postcentral': (3, 'Somatomotor_A'), # Sensitivo
    'SMA': (3, 'Somatomotor_A'), 'Supp_Motor_Area': (3, 'Somatomotor_A'),
    'LPC': (3, 'Somatomotor_A'), 'Paracentral_Lobule': (3, 'Somatomotor_A'),
    'T1': (4, 'Somatomotor_B'), 'Temporal_Sup': (4, 'Somatomotor_B'), # Auditivo
    'HESCHL': (4, 'Somatomotor_B'), 'Heschl': (4, 'Somatomotor_B'), # Auditivo primario
    'OR': (4, 'Somatomotor_B'), 'Rolandic_Oper': (4, 'Somatomotor_B'),

    # --- DORSAL ATTENTION (Yeo 5 & 6) ---
    'P1': (5, 'DorsalAttention_A'), 'Parietal_Sup': (5, 'DorsalAttention_A'),
    'O2': (6, 'DorsalAttention_B'), # A veces overlap aquí, pero lo dejamos en visual por anatomía

    # --- SALIENCE / VENTRAL ATTENTION (Yeo 7 & 8) ---
    'IN': (7, 'Salience_VentralAttention_A'), 'Insula': (7, 'Salience_VentralAttention_A'),
    'CINM': (7, 'Salience_VentralAttention_A'), 'Cingulate_Mid': (7, 'Salience_VentralAttention_A'),
    'F3OP': (8, 'Salience_VentralAttention_B'), 'Frontal_Inf_Oper': (8, 'Salience_VentralAttention_B'),
    'GSM': (8, 'Salience_VentralAttention_B'), 'SupraMarginal': (8, 'Salience_VentralAttention_B'),

    # --- LIMBIC (Yeo 9 & 10) - CRÍTICO PARA ALZHEIMER ---
    # Red 9: Polo Temporal / Límbico "Memoria/Emoción"
    'HIPP': (9, 'Limbic_A_TempPole'), 'Hippocampus': (9, 'Limbic_A_TempPole'),
    'PARA_HIPP': (9, 'Limbic_A_TempPole'), 'ParaHippocampal': (9, 'Limbic_A_TempPole'),
    'AMYG': (9, 'Limbic_A_TempPole'), 'Amygdala': (9, 'Limbic_A_TempPole'),
    'T1A': (9, 'Limbic_A_TempPole'), 'Temporal_Pole_Sup': (9, 'Limbic_A_TempPole'),
    'T2A': (9, 'Limbic_A_TempPole'), 'Temporal_Pole_Mid': (9, 'Limbic_A_TempPole'),
    'T3': (9, 'Limbic_A_TempPole'), 'Temporal_Inf': (9, 'Limbic_A_TempPole'), # A veces Visual, pero en AD su atrofia es clave

    # Red 10: Orbitofrontal (OFC) "Reward/Decision"
    'OFC': (10, 'Limbic_B_OFC'), 
    'GR': (10, 'Limbic_B_OFC'), 'Rectus': (10, 'Limbic_B_OFC'),
    'COB': (10, 'Limbic_B_OFC'), 'Olfactory': (10, 'Limbic_B_OFC'),
    'FMO': (10, 'Limbic_B_OFC'), 'Frontal_Med_Orb': (10, 'Limbic_B_OFC'),

    # --- CONTROL (Yeo 11, 12, 13) ---
    'F2': (12, 'Control_A'), 'Frontal_Mid': (12, 'Control_A'), # DLPFC approx
    'F3T': (12, 'Control_A'), 'Frontal_Inf_Tri': (12, 'Control_A'),
    'P2': (13, 'Control_B'), 'Parietal_Inf': (13, 'Control_B'),
    'F1': (13, 'Control_B'), 'Frontal_Sup': (13, 'Control_B'), # A veces DMN

    # --- DEFAULT MODE (Yeo 15, 16, 17) - EL "TARGET" DE ALZHEIMER ---
    'ANG': (15, 'DefaultMode_Core'), 'GA': (15, 'DefaultMode_Core'), 'Angular': (15, 'DefaultMode_Core'),
    'CIP': (15, 'DefaultMode_Core'), 'Cingulate_Post': (15, 'DefaultMode_Core'), # PCC
    'PQ': (16, 'DefaultMode_DorsalMedial'), 'Precuneus': (16, 'DefaultMode_DorsalMedial'),
    'FM': (17, 'DefaultMode_VentralMedial'), 'Frontal_Sup_Medial': (17, 'DefaultMode_VentralMedial'),
    'ACC': (17, 'DefaultMode_VentralMedial'), # Generalización para Anterior Cingulate
    'T2': (17, 'DefaultMode_VentralMedial'), 'Temporal_Mid': (17, 'DefaultMode_VentralMedial'),

    # --- SUBCORTICAL & CEREBELLUM (Background / Network 0) ---
    # Las CNNs funcionan mejor si esto está separado de la corteza
    'CER': (0, 'Background/NonCortical'),
    'VER': (0, 'Background/NonCortical'),
    'NC': (0, 'Background/NonCortical'), 'Caudate': (0, 'Background/NonCortical'),
    'NL': (0, 'Background/NonCortical'), 'Putamen': (0, 'Background/NonCortical'),
    'PAL': (0, 'Background/NonCortical'), 'Pallidum': (0, 'Background/NonCortical'),
    'THA': (0, 'Background/NonCortical'), 't': (0, 'Background/NonCortical'), # Thalamic nuclei
    'SN': (0, 'Background/NonCortical'),
    'VTA': (0, 'Background/NonCortical'),
    'Red': (0, 'Background/NonCortical'),
    'LC': (0, 'Background/NonCortical'),
    'Raphe': (0, 'Background/NonCortical'),
    'Vent': (0, 'Background/NonCortical')
}

# --- 2. PROCESAMIENTO ---

def generate_manual_mapping():
    print(f"Leyendo AAL3 meta desde: {AAL3_TXT_PATH}")
    
    # A. Leer y Limpiar como el pipeline original
    try:
        df = pd.read_csv(AAL3_TXT_PATH, sep='\s+', engine='python') # \s+ maneja espacios o tabs
        # Asegurar nombres de columnas correctos si el txt tiene header raro
        if 'nom_c' not in df.columns:
            # Fallback: asumir orden nom_c, nom_l, color...
            df = pd.read_csv(AAL3_TXT_PATH, sep='\s+', names=['nom_c', 'nom_l', 'color', 'vol_vox', 'vol_mm3'], header=0)
    except Exception as e:
        print(f"Error leyendo txt: {e}")
        return

    # Filtros del pipeline (Hardcoded para replicar feature_extraction.py)
    MISSING_INDICES = [35, 36, 81, 82]
    MIN_VOXELS = 100
    
    # Aplicar filtros
    df = df[~df['color'].isin(MISSING_INDICES)].copy()
    df = df[df['vol_vox'] >= MIN_VOXELS].copy()
    
    print(f"ROIs después de filtrado (debe ser 131): {len(df)}")
    if len(df) != 131:
        print("⚠️ CUIDADO: No obtuvimos 131 ROIs. Revisa los filtros.")

    # B. Asignar Redes y Parsear Lado
    data_rows = []
    
    for _, row in df.iterrows():
        name_c = str(row['nom_c'])
        
        # 1. Detectar Lado (L/R) y BaseName
        # Regex busca terminación L o R. Ej: "HIPPOL" -> Base="HIPPO", Side="L"
        # Maneja casos como "F1_2L" -> Base="F1_2"
        match = re.search(r'^(.*)(L|R)$', name_c)
        if match:
            base_name = match.group(1)
            side_char = match.group(2)
            # Limpieza extra para guiones bajos residuales
            if base_name.endswith('_'): base_name = base_name[:-1]
        else:
            # Casos sin lado claro o Vermis
            base_name = name_c
            side_char = 'Z' # Z para ordenar al final (Midline)

        # 2. Asignar Red Yeo (Búsqueda en Diccionario)
        yeo_id = 0
        yeo_net = "Background/NonCortical"
        
        # Buscamos coincidencia exacta o prefijo
        # Prioridad a claves más largas para evitar falsos positivos (ej T1 vs T1A)
        keys = sorted(YEO_MAPPING.keys(), key=len, reverse=True)
        for k in keys:
            if base_name.startswith(k):
                yeo_id, yeo_net = YEO_MAPPING[k]
                break
        
        # 3. Guardar para sorting
        data_rows.append({
            'Index_131': 0, # Placeholder, se llena después
            'nom_c': name_c,
            'nom_l': row['nom_l'],
            'color': row['color'],
            'vol_vox': row['vol_vox'],
            'vol_mm3': row['vol_mm3'],
            'Yeo17_Label_manual': yeo_id,
            'Yeo17_Network_manual': yeo_net,
            'Hemi': side_char,
            'BaseName': base_name
        })

    df_mapped = pd.DataFrame(data_rows)

    # C. ORDENAMIENTO INTELIGENTE PARA CNN
    # 1. Red Funcional (Corticales 1-17 primero, Background 0 al final)
    df_mapped['__sort_bg'] = (df_mapped['Yeo17_Label_manual'] == 0).astype(int)
    
    # 2. Red ID
    # 3. Base Name (Alfabético para agrupar estructuras iguales)
    # 4. Hemi (L=0 antes que R=1 para ponerlos adyacentes)
    df_mapped['__sort_hemi'] = df_mapped['Hemi'].map({'L': 0, 'R': 1, 'Z': 2})
    
    df_sorted = df_mapped.sort_values(
        by=['__sort_bg', 'Yeo17_Label_manual', 'BaseName', '__sort_hemi']
    ).reset_index(drop=True)

    # Asignar el índice final 0..130
    # Este índice le dice al script: "El ROI que era columna X, ahora ponlo en columna Index_131"
    # ESPERA: El script feature_extraction_manual espera que 'Index_131' sea el índice 
    # ORIGINAL en la matriz filtrada de 131. 
    # Necesitamos preservar el orden original "crudo" para saber qué columna mover.
    # El script manual hace un merge por 'nom_c'. Así que 'Index_131' en el CSV 
    # debería ser la POSICIÓN DESTINO o la POSICIÓN ORIGEN?
    # Revisando el código: 
    # mapping_df = mapping_df.sort_values("Index_131") 
    # new_order_indices = mapping_df["Index_131"]
    # Ah! El código asume que Index_131 es una permutación. 
    # Vamos a simplificar: El código hace merge por 'nom_c'. 
    # Lo que define el orden final es EL ORDEN DE LAS FILAS EN EL CSV.
    # Entonces, Index_131 en el CSV debe reflejar el índice ORIGINAL (0..130) antes de ordenar.
    
    # Recuperar índice original (basado en color ascendente, como hace el pipeline)
    df_original_order = df.sort_values(by='color').reset_index(drop=True)
    name_to_orig_idx = {name: i for i, name in enumerate(df_original_order['nom_c'])}
    
    df_sorted['Index_131'] = df_sorted['nom_c'].map(name_to_orig_idx)
    
    # Limpiar columnas auxiliares
    cols_out = ['Index_131', 'nom_c', 'nom_l', 'color', 'vol_vox', 'vol_mm3', 
                'Yeo17_Label_manual', 'Yeo17_Network_manual', 'Hemi']
    df_final = df_sorted[cols_out]

    # D. Guardar
    OUTPUT_CSV_PATH.parent.mkdir(parents=True, exist_ok=True)
    df_final.to_csv(OUTPUT_CSV_PATH, index=False)
    print(f"\n✅ Archivo de Ordenamiento Manual generado exitosamente:")
    print(f"   {OUTPUT_CSV_PATH}")
    print("\nPrimeras 10 filas (Orden Optimo para CNN):")
    print(df_final[['nom_c', 'Yeo17_Network_manual', 'Hemi']].head(10))
    print("\nVerificación Pares Hipocampo (Deberían estar juntos):")
    print(df_final[df_final['nom_c'].str.contains('HIPP')][['nom_c', 'Yeo17_Network_manual']])

# Ejecutar
generate_manual_mapping()
# Out:
# Leyendo AAL3 meta desde: /home/diego/proyectos/betavae-xai-ad/data/ROI_MNI_V7_vol.txt
# ROIs después de filtrado (debe ser 131): 131
#
# ✅ Archivo de Ordenamiento Manual generado exitosamente:
#    /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
#
# Primeras 10 filas (Orden Optimo para CNN):
#    nom_c Yeo17_Network_manual Hemi
# 0  FUSIL    Visual_Peripheral    L
# 1  FUSIR    Visual_Peripheral    R
# 2  LINGL    Visual_Peripheral    L
# 3  LINGR    Visual_Peripheral    R
# 4    O1L    Visual_Peripheral    L
# 5    O1R    Visual_Peripheral    R
# 6    O3L    Visual_Peripheral    L
# 7    O3R    Visual_Peripheral    R
# 8     QL    Visual_Peripheral    L
# 9     QR    Visual_Peripheral    R
#
# Verificación Pares Hipocampo (Deberían estar juntos):
#           nom_c Yeo17_Network_manual
# 40       HIPPOL    Limbic_A_TempPole
# 41       HIPPOR    Limbic_A_TempPole
# 42  PARA_HIPPOL    Limbic_A_TempPole
# 43  PARA_HIPPOR    Limbic_A_TempPole

# %%
import sys
from pathlib import Path
from importlib import reload

# 1) Asegurar path a src/
PROJECT_ROOT = Path("..").resolve()
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# 2) Importar y recargar el módulo manual
from betavae_xai import feature_extraction_manual as fem
reload(fem)

print("=== DIAGNÓSTICO RÁPIDO DE IMPORT ===")
print(f"Ruta del módulo: {fem.__file__}")
print(f"FINAL_N_ROIS_EXPECTED: {fem.FINAL_N_ROIS_EXPECTED}")
print(f"OUTPUT_CONNECTIVITY_DIR_NAME: {fem.OUTPUT_CONNECTIVITY_DIR_NAME}")
print(f"CONNECTIVITY_CHANNEL_NAMES: {fem.CONNECTIVITY_CHANNEL_NAMES}")
print(f"N_CHANNELS: {fem.N_CHANNELS}")
# Out:
# 2025-11-22 14:54:42,570 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:54:42,570 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:54:42,571 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:54:42,577 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:54:42,577 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:54:42,578 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:54:42,578 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:54:42,579 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:54:42,579 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:54:42,579 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:54:42,587 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:54:42,587 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:54:42,588 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:54:42,588 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:54:42,589 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:54:42,589 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:54:42,589 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:54:42,590 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:54:42,590 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:54:42,591 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:54:42,591 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:54:42,592 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:54:42,593 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:54:42,594 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:54:42,594 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:54:42,595 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:54:42,595 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:54:42,595 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:54:42,596 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:54:42,596 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:54:42,597 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:54:42,597 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:54:42,597 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:54:42,597 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:54:42,598 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:54:42,598 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:54:42,598 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:54:42,599 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# === DIAGNÓSTICO RÁPIDO DE IMPORT ===
# Ruta del módulo: /home/diego/proyectos/betavae-xai-ad/src/betavae_xai/feature_extraction_manual.py
# FINAL_N_ROIS_EXPECTED: 131
# OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# CONNECTIVITY_CHANNEL_NAMES: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# N_CHANNELS: 7

# %%
from importlib import reload
import pandas as pd

reload(fem)  # por si tocaste el .py desde fuera

print("=== AAL3 MANUAL MAPPING CHECK ===")
print("CSV esperado en:", fem.AAL3_MANUAL_NETWORK_MAPPING_CSV)

# 1) Ver que el mapping global del módulo está bien
m = fem.AAL3_ROI_ORDER_MAPPING
if m is None or m.get("new_order_indices") is None:
    print("❌ AAL3_ROI_ORDER_MAPPING es None o no tiene 'new_order_indices'.")
else:
    print("✅ Mapping cargado desde módulo.")
    print("  order_name:", m.get("order_name"))
    print("  Nº ROIs new_order:", len(m.get("roi_names_new_order", [])))
    print("  Nº índices new_order_indices:", len(m.get("new_order_indices", [])))

    print("\nPrimeras 10 ROIs en el NUEVO orden:")
    roi_names = m["roi_names_new_order"]
    net_labels = m["network_labels_new_order"]
    for i in range(10):
        print(f"{i:3d}  {roi_names[i]:25s} → {net_labels[i]}")

# 2) Leer el CSV para ver un resumen por red
try:
    df_map = pd.read_csv(fem.AAL3_MANUAL_NETWORK_MAPPING_CSV)
    print("\nCSV cargado. Shape:", df_map.shape)

    candidates = ["Yeo17_Network_manual", "Yeo17_Network", "NetworkName", "Network"]
    net_col = next((c for c in candidates if c in df_map.columns), None)
    if net_col is not None:
        print("\nConteo de ROIs por red (desde CSV):")
        print(df_map[net_col].value_counts())
    else:
        print("\nNo encontré una columna de nombre de red en el CSV. Solo labels numéricos.")
except Exception as e:
    print("Error leyendo el CSV manual:", e)
# Out:
# 2025-11-22 14:54:46,036 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:54:46,037 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:54:46,038 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:54:46,043 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:54:46,043 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:54:46,044 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:54:46,044 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:54:46,045 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:54:46,045 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:54:46,045 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:54:46,053 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:54:46,053 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:54:46,053 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:54:46,054 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:54:46,054 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:54:46,054 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:54:46,054 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:54:46,054 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:54:46,055 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:54:46,055 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:54:46,055 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:54:46,055 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:54:46,056 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:54:46,056 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:54:46,057 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:54:46,058 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:54:46,058 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:54:46,059 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:54:46,059 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:54:46,060 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:54:46,061 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:54:46,061 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:54:46,061 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:54:46,062 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:54:46,063 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:54:46,063 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:54:46,064 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:54:46,064 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# === AAL3 MANUAL MAPPING CHECK ===
# CSV esperado en: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# ✅ Mapping cargado desde módulo.
#   order_name: aal3_manual_yeo17_order
#   Nº ROIs new_order: 131
#   Nº índices new_order_indices: 131
#
# Primeras 10 ROIs en el NUEVO orden:
#   0  Cuneus_L                  → Visual_Peripheral
#   1  Fusiform_L                → Visual_Peripheral
#   2  Lingual_L                 → Visual_Peripheral
#   3  Occipital_Inf_L           → Visual_Peripheral
#   4  Occipital_Sup_L           → Visual_Peripheral
#   5  Cuneus_R                  → Visual_Peripheral
#   6  Fusiform_R                → Visual_Peripheral
#   7  Lingual_R                 → Visual_Peripheral
#   8  Occipital_Inf_R           → Visual_Peripheral
#   9  Occipital_Sup_R           → Visual_Peripheral
#
# CSV cargado. Shape: (131, 9)
#
# Conteo de ROIs por red (desde CSV):
# Yeo17_Network_manual
# Background/NonCortical         43
# Limbic_B_OFC                   14
# Limbic_A_TempPole              12
# Visual_Peripheral              10
# DefaultMode_VentralMedial      10
# Somatomotor_A                   8
# Somatomotor_B                   6
# Salience_VentralAttention_B     4
# Control_B                       4
# Control_A                       4
# DefaultMode_Core                4
# Salience_VentralAttention_A     4
# DorsalAttention_A               2
# DorsalAttention_B               2
# Visual_Central                  2
# DefaultMode_DorsalMedial        2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df_map = pd.read_csv(fem.AAL3_MANUAL_NETWORK_MAPPING_CSV)

net_col_candidates = ["Yeo17_Network_manual", "Yeo17_Network", "NetworkName", "Network"]
net_col = next((c for c in net_col_candidates if c in df_map.columns), None)
if net_col is None:
    raise ValueError(f"No pude encontrar columna de nombre de red entre: {net_col_candidates}")

networks = df_map[net_col].values
unique_networks = list(dict.fromkeys(networks))  # preserva orden de aparición
net_to_int = {net: i for i, net in enumerate(unique_networks)}
network_colors = [net_to_int[n] for n in networks]

plt.figure(figsize=(14, 2.5))
plt.imshow([network_colors], aspect="auto", cmap="tab20")
plt.yticks([])
plt.xlabel("Índice de ROI (0..130)")
plt.title("ROIs AAL3 (131) en nuevo orden manual Yeo-17")

for net in unique_networks:
    idx = np.where(networks == net)[0]
    if len(idx) == 0:
        continue
    center = np.mean(idx)
    plt.text(center, 0, net, rotation=90, ha="center", va="center",
             fontsize=7, color="white", fontweight="bold")

plt.tight_layout()
plt.show()

# %%
from importlib import reload

reload(fem)

print("=== RESUMEN ANTES DE CORRER main() ===")
print("FINAL_N_ROIS_EXPECTED:", fem.FINAL_N_ROIS_EXPECTED)
print("OUTPUT_CONNECTIVITY_DIR_NAME:", fem.OUTPUT_CONNECTIVITY_DIR_NAME)
print("CONNECTIVITY_CHANNEL_NAMES:", fem.CONNECTIVITY_CHANNEL_NAMES)
print("ROI reordering activo?:",
      "Sí" if fem.AAL3_ROI_ORDER_MAPPING and fem.AAL3_ROI_ORDER_MAPPING.get("new_order_indices") is not None else "No")

# ⚠️ Esto dispara todo el pipeline (multiprocessing, etc.).
fem.main()
# Out:
# 2025-11-22 14:55:58,733 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:55:58,733 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:55:58,734 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:55:58,739 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:55:58,739 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:55:58,740 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:55:58,740 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:55:58,741 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:55:58,742 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:55:58,742 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:55:58,748 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:55:58,749 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:55:58,750 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:55:58,750 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:55:58,751 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:55:58,751 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:55:58,752 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:55:58,752 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:55:58,753 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:55:58,753 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:55:58,754 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:55:58,754 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:55:58,755 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:55:58,755 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:55:58,756 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:55:58,757 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:55:58,757 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:55:58,757 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:55:58,758 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:55:58,758 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:55:58,759 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:55:58,759 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:55:58,760 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:55:58,761 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:55:58,761 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:55:58,762 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:55:58,762 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:55:58,762 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:55:58,763 - INFO - feature_extraction_manual.py:1823 - RUNTIME NetworkX version being used: 2.6.3
# 2025-11-22 14:55:58,765 - INFO - feature_extraction_manual.py:1834 - Main process RAM at start: 416.59 MB
# 2025-11-22 14:55:58,766 - INFO - feature_extraction_manual.py:1835 - --- Starting fMRI Connectivity Pipeline (Version: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17) ---
# 2025-11-22 14:55:58,766 - INFO - feature_extraction_manual.py:1841 - --- Final Expected ROIs for Connectivity Matrices: 131 ---
# 2025-11-22 14:55:58,767 - INFO - feature_extraction_manual.py:1842 - --- Target Homogenized Time Series Length: 140 ---
# 2025-11-22 14:55:58,767 - INFO - feature_extraction_manual.py:1843 - --- Output Directory Name: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned ---
# 2025-11-22 14:55:58,768 - INFO - feature_extraction_manual.py:1844 - --- Selected Connectivity Channels for VAE: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1'] (7 channels) ---
# 2025-11-22 14:55:58,768 - INFO - feature_extraction_manual.py:1845 - --- Per-subject, per-channel normalization with RobustScaler (off-diagonal) will be applied before stacking. ---
# 2025-11-22 14:55:58,769 - INFO - feature_extraction_manual.py:1848 - --- ROI reordering by network is currently: ACTIVE (Yeo-17 mapping implemented). ---
# 2025-11-22 14:55:58,769 - INFO - feature_extraction_manual.py:593 - --- Starting Subject Metadata Loading and QC Integration ---
# 2025-11-22 14:55:58,775 - INFO - feature_extraction_manual.py:604 - Loaded main metadata from /home/diego/proyectos/betavae-xai-ad/data/SubjectsData_AAL3_procesado2.csv. Shape: (434, 33)
# 2025-11-22 14:55:58,781 - INFO - feature_extraction_manual.py:612 - Loaded QC report from /home/diego/proyectos/betavae-xai-ad/notebooks/qc_outputs_doctoral/report_qc_final_with_discard_flags_v3.2.csv. Shape: (434, 34)
# 2025-11-22 14:55:58,782 - INFO - feature_extraction_manual.py:615 - Found 'Subject' column in QC report, renaming to 'SubjectID'.
# 2025-11-22 14:55:58,788 - INFO - feature_extraction_manual.py:647 - SUGGESTION (Data Quality): Review 'ToDiscard_Overall' criteria from QC script. Consider if stricter thresholds for subject exclusion (e.g., based on percentage of multivariate outliers, mean FD, DVARS) would yield a cleaner dataset for modeling, even if N is slightly reduced. Ensure discard rate is similar across groups.
# 2025-11-22 14:55:58,790 - INFO - feature_extraction_manual.py:653 - Total subjects after merge: 434
# 2025-11-22 14:55:58,790 - INFO - feature_extraction_manual.py:654 - Subjects discarded based on QC ('ToDiscard_Overall' == True): 3
# 2025-11-22 14:55:58,791 - INFO - feature_extraction_manual.py:655 - Subjects passing QC and to be processed: 431
# 2025-11-22 14:55:58,792 - INFO - feature_extraction_manual.py:663 - Timepoints for subjects passing QC (from QC report): Min=140, Max=200.
# 2025-11-22 14:55:58,792 - INFO - feature_extraction_manual.py:664 - These will be homogenized to TARGET_LEN_TS = 140 for connectivity calculation.
# 2025-11-22 14:55:58,794 - INFO - feature_extraction_manual.py:1872 - Main output directory created/exists: /home/diego/proyectos/betavae-xai-ad/data/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:55:58,794 - INFO - feature_extraction_manual.py:1876 - Total CPU cores available: 12. Using MAX_WORKERS = 6 for ProcessPoolExecutor.
# 2025-11-22 14:55:58,794 - WARNING - feature_extraction_manual.py:1878 - Available system RAM at start of parallel processing: 8.53 GB. Monitor usage closely.
# 2025-11-22 14:55:58,808 - INFO - feature_extraction_manual.py:1885 - Starting parallel processing for 431 subjects.
# === RESUMEN ANTES DE CORRER main() ===
# FINAL_N_ROIS_EXPECTED: 131
# OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# CONNECTIVITY_CHANNEL_NAMES: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# ROI reordering activo?: Sí
# Processing Subjects:   0%|          | 0/431 [00:00<?, ?it/s]2025-11-22 14:55:59,081 - INFO - feature_extraction_manual.py:711 - S 002_S_0729: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-11-22 14:55:59,081 - INFO - feature_extraction_manual.py:711 - S 002_S_2010: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-11-22 14:55:59,082 - INFO - feature_extraction_manual.py:711 - S 002_S_0295: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-11-22 14:55:59,083 - INFO - feature_extraction_manual.py:888 - S 002_S_2010: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s. Target TPs for output: 140.
# 2025-11-22 14:55:59,083 - INFO - feature_extraction_manual.py:888 - S 002_S_0295: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s. Target TPs for output: 140.
# 2025-11-22 14:55:59,084 - INFO - feature_extraction_manual.py:888 - S 002_S_0729: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s. Target TPs for output: 140.
# 2025-11-22 14:55:59,084 - INFO - feature_extraction_manual.py:711 - S 002_S_0413: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-11-22 14:55:59,085 - INFO - feature_extraction_manual.py:888 - S 002_S_0413: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s. Target TPs for output: 140.
# 2025-11-22 14:55:59,095 - INFO - feature_extraction_manual.py:711 - S 002_S_0685: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-11-22 14:55:59,095 - INFO - feature_extraction_manual.py:711 - S 002_S_1155: Reordenando series temporales de ROIs ((197, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-11-22 14:55:59,097 - INFO - feature_extraction_manual.py:888 - S 002_S_0685: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s. Target TPs for output: 140.
# 2025-11-22 14:55:59,097 - INFO - feature_extraction_manual.py:888 - S 002_S_1155: Preprocessing. Input TPs: 197, ROIs: 131 (should be 131), TR: 3.0s. Target TPs for output: 140.
# 2025-11-22 14:55:59,121 - INFO - feature_extraction_manual.py:933 - S 002_S_1155: Homogenizing time series length from 197 to 140.
# 2025-11-22 14:55:59,271 - INFO - feature_extraction_manual.py:1025 - S 002_S_2010: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-11-22 14:55:59,272 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_OMST_GCE_Signed_Weighted for S 002_S_2010 (TS shape: (140, 131))...
# 2025-11-22 14:55:59,272 - INFO - feature_extraction_manual.py:1025 - S 002_S_0413: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-11-22 14:55:59,273 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_OMST_GCE_Signed_Weighted for S 002_S_0413 (TS shape: (140, 131))...
# 2025-11-22 14:55:59,279 - INFO - feature_extraction_manual.py:1025 - S 002_S_0729: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-11-22 14:55:59,283 - INFO - feature_extraction_manual.py:1025 - S 002_S_1155: Successfully loaded and preprocessed. Original TPs: 197, Final Shape for conn: (140, 131)
# 2025-11-22 14:55:59,279 - INFO - feature_extraction_manual.py:1025 - S 002_S_0295: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-11-22 14:55:59,290 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_OMST_GCE_Signed_Weighted for S 002_S_0729 (TS shape: (140, 131))...
# 2025-11-22 14:55:59,294 - INFO - feature_extraction_manual.py:1025 - S 002_S_0685: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-11-22 14:55:59,294 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_OMST_GCE_Signed_Weighted for S 002_S_0295 (TS shape: (140, 131))...
# 2025-11-22 14:55:59,305 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_OMST_GCE_Signed_Weighted for S 002_S_0685 (TS shape: (140, 131))...
# 2025-11-22 14:55:59,315 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_OMST_GCE_Signed_Weighted for S 002_S_1155 (TS shape: (140, 131))...
# 2025-11-22 14:56:55,717 - INFO - feature_extraction_manual.py:1563 - Pearson_OMST_GCE_Signed_Weighted for S 002_S_0413 calculated. Shape: (131, 131). Took 56.44s.
# 2025-11-22 14:56:55,718 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_Full_FisherZ_Signed for S 002_S_0413 (TS shape: (140, 131))...
# 2025-11-22 14:56:55,746 - INFO - feature_extraction_manual.py:1563 - Pearson_Full_FisherZ_Signed for S 002_S_0413 calculated. Shape: (131, 131). Took 0.03s.
# 2025-11-22 14:56:55,768 - INFO - feature_extraction_manual.py:1480 - Calculating MI_KNN_Symmetric for S 002_S_0413 (TS shape: (140, 131))...
# 2025-11-22 14:56:57,523 - INFO - feature_extraction_manual.py:1563 - Pearson_OMST_GCE_Signed_Weighted for S 002_S_0729 calculated. Shape: (131, 131). Took 58.22s.
# 2025-11-22 14:56:57,524 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_Full_FisherZ_Signed for S 002_S_0729 (TS shape: (140, 131))...
# 2025-11-22 14:56:57,548 - INFO - feature_extraction_manual.py:1563 - Pearson_Full_FisherZ_Signed for S 002_S_0729 calculated. Shape: (131, 131). Took 0.02s.
# 2025-11-22 14:56:57,568 - INFO - feature_extraction_manual.py:1480 - Calculating MI_KNN_Symmetric for S 002_S_0729 (TS shape: (140, 131))...
# 2025-11-22 14:56:58,847 - INFO - feature_extraction_manual.py:1563 - Pearson_OMST_GCE_Signed_Weighted for S 002_S_1155 calculated. Shape: (131, 131). Took 59.49s.
# 2025-11-22 14:56:58,848 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_Full_FisherZ_Signed for S 002_S_1155 (TS shape: (140, 131))...
# 2025-11-22 14:56:58,864 - INFO - feature_extraction_manual.py:1563 - Pearson_Full_FisherZ_Signed for S 002_S_1155 calculated. Shape: (131, 131). Took 0.02s.
# 2025-11-22 14:56:58,896 - INFO - feature_extraction_manual.py:1480 - Calculating MI_KNN_Symmetric for S 002_S_1155 (TS shape: (140, 131))...
# 2025-11-22 14:56:59,890 - INFO - feature_extraction_manual.py:1563 - Pearson_OMST_GCE_Signed_Weighted for S 002_S_2010 calculated. Shape: (131, 131). Took 60.62s.
# 2025-11-22 14:56:59,891 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_Full_FisherZ_Signed for S 002_S_2010 (TS shape: (140, 131))...
# 2025-11-22 14:56:59,952 - INFO - feature_extraction_manual.py:1563 - Pearson_Full_FisherZ_Signed for S 002_S_2010 calculated. Shape: (131, 131). Took 0.06s.
# 2025-11-22 14:56:59,968 - INFO - feature_extraction_manual.py:1480 - Calculating MI_KNN_Symmetric for S 002_S_2010 (TS shape: (140, 131))...
# 2025-11-22 14:57:00,631 - INFO - feature_extraction_manual.py:1563 - Pearson_OMST_GCE_Signed_Weighted for S 002_S_0295 calculated. Shape: (131, 131). Took 61.32s.
# 2025-11-22 14:57:00,633 - INFO - feature_extraction_manual.py:1480 - Calculating Pearson_Full_FisherZ_Signed for S 002_S_0295 (TS shape: (140, 131))...
# 2025-11-22 14:57:00,660 - INFO - feature_extraction_manual.py:1563 - Pearson_Full_FisherZ_Signed for S 002_S_0295 calculated. Shape: (131, 131). Took 0.03s.
# 2025-11-22 14:57:00,674 - INFO - feature_extraction_manual.py:1480 - Calculating MI_KNN_Symmetric for S 002_S_0295 (TS shape: (140, 131))...
# 2025-11-22 14:57:04,937 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:57:04,938 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:57:04,938 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:57:04,945 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:57:04,953 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:57:04,953 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:57:04,954 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:57:04,954 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:57:04,954 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:57:04,954 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:57:04,954 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:57:04,955 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:04,994 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:57:04,995 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:57:04,996 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:57:05,002 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:57:05,003 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:57:05,003 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:57:05,003 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:57:05,004 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:57:05,004 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:57:05,004 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:57:05,012 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:57:05,012 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:57:05,013 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:57:05,013 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:57:05,013 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:57:05,013 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:57:05,013 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:05,014 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:57:05,014 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:57:05,014 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:57:05,014 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:57:05,014 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:57:05,015 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:57:05,015 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:57:05,015 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:57:05,015 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:57:05,015 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:57:05,015 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:57:05,016 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:57:05,017 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:57:05,017 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:57:05,017 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:06,962 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:57:06,963 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:57:06,963 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:57:06,968 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:57:06,968 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:57:06,968 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:57:06,968 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:57:06,969 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:57:06,969 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:57:06,969 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:57:06,975 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:57:06,976 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:57:06,976 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:57:06,976 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:57:06,976 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:57:06,976 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:57:06,976 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:57:06,977 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:07,370 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:57:07,371 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:57:07,371 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:57:07,377 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:57:07,377 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:57:07,377 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:57:07,378 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:57:07,378 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:57:07,378 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:57:07,378 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:57:07,385 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:57:07,385 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:57:07,385 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:57:07,385 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:57:07,385 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:57:07,385 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:57:07,385 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:07,385 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# 2025-11-22 14:57:07,385 - CRITICAL - feature_extraction_manual.py:567 - !! La calidad de las matrices de conectividad depende DIRECTAMENTE de este preprocesamiento previo.     !!
# 2025-11-22 14:57:07,385 - CRITICAL - feature_extraction_manual.py:568 - !! Este preprocesamiento DEBERÍA HABER INCLUIDO (como mínimo):                                       !!
# 2025-11-22 14:57:07,385 - CRITICAL - feature_extraction_manual.py:569 - !!   - Corrección de movimiento (realineación).                                                       !!
# 2025-11-22 14:57:07,385 - CRITICAL - feature_extraction_manual.py:570 - !!   - Coregistro a imagen anatómica T1w.                                                             !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:571 - !!   - Normalización a un espacio estándar (ej. MNI).                                                 !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:572 - !!   - SCRUBBING/CENSURA de volúmenes con movimiento excesivo (ej. FD > 0.5mm, DVARS anómalo).        !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:573 - !!     (Si no se hizo, considerar implementarlo ANTES o adaptando este script si se dispone de FD/DVARS por TP). !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:574 - !!     (Revisar umbrales de scrubbing; FD > 0.2mm con DVARS adaptativo podría ser más sensible).       !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:575 - !!   - REGRESIÓN DE CONFOUNDS:                                                                        !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:576 - !!     - Parámetros de movimiento (ej. 6 básicos + derivadas + cuadrados = 24 parámetros).            !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:577 - !!     - Señales medias de sustancia blanca (WM) y líquido cefalorraquídeo (CSF).                     !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:578 - !!     - Componentes de CompCor (anatómico o temporal, aCompCor/tCompCor) son altamente recomendables.  !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:579 - !!     - Regresión fisiológica avanzada (RETROICOR/PhysIO si se dispone de datos de pulso/respiración). !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:580 - !!     - Considerar ICA-AROMA o FIX para eliminar componentes de movimiento residuales.               !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:581 - !!     - Considerar Global Signal Regression (GSR) con conocimiento de sus efectos (puede inducir     !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:582 - !!       anti-correlaciones pero también mejorar la especificidad de la red). Evaluar con/sin GSR.    !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:583 - !!   - Filtrado temporal (ej. pasabanda) si no se realiza en este script (aquí se aplica 0.01-0.08Hz). !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:584 - !! SI ESTOS PASOS NO SE HAN REALIZADO, LA INTERPRETACIÓN NEUROCIENTÍFICA DE LOS RESULTADOS PUEDE VERSE !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:585 - !! SEVERAMENTE COMPROMETIDA POR ARTEFACTOS Y RUIDO.                                                 !!
# 2025-11-22 14:57:07,386 - CRITICAL - feature_extraction_manual.py:586 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:08,477 - INFO - feature_extraction_manual.py:54 - Successfully imported 'threshold_omst_global_cost_efficiency' from 'dyconnmap.graphs.threshold' and aliased as 'orthogonal_minimum_spanning_tree'.
# 2025-11-22 14:57:08,478 - INFO - feature_extraction_manual.py:188 - Global MAX_WORKERS for ProcessPoolExecutor set to: 6 (based on 12 total cores)
# 2025-11-22 14:57:08,478 - INFO - feature_extraction_manual.py:447 - --- Initializing AAL3 ROI Processing Information ---
# 2025-11-22 14:57:08,483 - INFO - feature_extraction_manual.py:486 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-11-22 14:57:08,483 - INFO - feature_extraction_manual.py:487 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-11-22 14:57:08,484 - INFO - feature_extraction_manual.py:488 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-11-22 14:57:08,484 - INFO - feature_extraction_manual.py:489 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-11-22 14:57:08,484 - INFO - feature_extraction_manual.py:490 -   Number of small ROIs to drop: 35
# 2025-11-22 14:57:08,484 - INFO - feature_extraction_manual.py:491 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-11-22 14:57:08,484 - INFO - feature_extraction_manual.py:235 - Attempting to build MANUAL AAL3 -> Yeo-17 mapping and ROI order (no NIfTI overlap).
# 2025-11-22 14:57:08,491 - INFO - feature_extraction_manual.py:426 - Successfully built MANUAL AAL3->Yeo17 mapping and new ROI order from CSV: /home/diego/proyectos/betavae-xai-ad/data/aal3_131_manual_network_order.csv
# 2025-11-22 14:57:08,491 - INFO - feature_extraction_manual.py:503 - ROI reordering WILL BE APPLIED based on 'aal3_manual_yeo17_order'.
# 2025-11-22 14:57:08,492 - INFO - feature_extraction_manual.py:558 - Final N_ROIS_EXPECTED after initialization: 131
# 2025-11-22 14:57:08,492 - INFO - feature_extraction_manual.py:559 - Final OUTPUT_CONNECTIVITY_DIR_NAME: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 14:57:08,492 - INFO - feature_extraction_manual.py:560 - Connectivity channels to be computed: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# 2025-11-22 14:57:08,492 - INFO - feature_extraction_manual.py:561 - Total number of channels (for VAE): 7
# 2025-11-22 14:57:08,492 - CRITICAL - feature_extraction_manual.py:565 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 14:57:08,492 - CRITICAL - feature_extraction_manual.py:566 - !! CRÍTICO: Este script ASUME que las señales BOLD de los ROIs ya han sido PREPROCESADAS RIGUROSAMENTE !!
# ...
#   warnings.warn(
# 2025-11-22 17:38:28,569 - INFO - feature_extraction_manual.py:1563 - Granger_F_lag1 for S 305_S_6881 calculated. Shape: (131, 131). Took 9.79s.
# 2025-11-22 17:38:28,570 - INFO - feature_extraction_manual.py:1593 - Connectivity for S 305_S_6881: All 7/7 selected modalities computed successfully.
# 2025-11-22 17:38:28,870 - INFO - feature_extraction_manual.py:1733 - S 305_S_6881: Successfully processed. Tensor (with channel normalization) saved to tensor_7ch_131rois_305_S_6881.npz
# Processing Subjects:  99%|█████████▉| 428/431 [2:42:30<01:07, 22.53s/it]2025-11-22 17:38:35,293 - INFO - feature_extraction_manual.py:1563 - MI_KNN_Symmetric for S 941_S_4187 calculated. Shape: (131, 131). Took 13.70s.
# 2025-11-22 17:38:35,293 - INFO - feature_extraction_manual.py:1480 - Calculating dFC_AbsDiffMean for S 941_S_4187 (TS shape: (140, 131))...
# 2025-11-22 17:38:35,848 - INFO - feature_extraction_manual.py:1563 - dFC_AbsDiffMean for S 941_S_4187 calculated. Shape: (131, 131). Took 0.55s.
# 2025-11-22 17:38:35,868 - INFO - feature_extraction_manual.py:1480 - Calculating dFC_StdDev for S 941_S_4187 (TS shape: (140, 131))...
# 2025-11-22 17:38:36,007 - INFO - feature_extraction_manual.py:1563 - dFC_StdDev for S 941_S_4187 calculated. Shape: (131, 131). Took 0.12s.
# 2025-11-22 17:38:36,008 - INFO - feature_extraction_manual.py:1480 - Calculating DistanceCorr for S 941_S_4187 (TS shape: (140, 131))...
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/dcor/_fast_dcov_avl.py:554: UserWarning: Falling back to uncompiled AVL fast distance covariance terms because of TypeError exception raised: No matching definition for argument type(s) array(float32, 1d, C), array(float32, 1d, C), bool. Rembember: only floating point values can be used in the compiled implementations.
#   warnings.warn(
# 2025-11-22 17:38:37,092 - INFO - feature_extraction_manual.py:1563 - Granger_F_lag1 for S 305_S_6899 calculated. Shape: (131, 131). Took 9.10s.
# 2025-11-22 17:38:37,093 - INFO - feature_extraction_manual.py:1593 - Connectivity for S 305_S_6899: All 7/7 selected modalities computed successfully.
# 2025-11-22 17:38:37,369 - INFO - feature_extraction_manual.py:1733 - S 305_S_6899: Successfully processed. Tensor (with channel normalization) saved to tensor_7ch_131rois_305_S_6899.npz
# Processing Subjects: 100%|█████████▉| 429/431 [2:42:38<00:36, 18.31s/it]2025-11-22 17:38:42,786 - INFO - feature_extraction_manual.py:1563 - DistanceCorr for S 941_S_4036 calculated. Shape: (131, 131). Took 26.47s.
# 2025-11-22 17:38:42,787 - INFO - feature_extraction_manual.py:1480 - Calculating Granger_F_lag1 for S 941_S_4036 (TS shape: (140, 131))...
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# 2025-11-22 17:38:50,797 - INFO - feature_extraction_manual.py:1563 - Granger_F_lag1 for S 941_S_4036 calculated. Shape: (131, 131). Took 8.01s.
# 2025-11-22 17:38:50,798 - INFO - feature_extraction_manual.py:1593 - Connectivity for S 941_S_4036: All 7/7 selected modalities computed successfully.
# 2025-11-22 17:38:51,024 - INFO - feature_extraction_manual.py:1733 - S 941_S_4036: Successfully processed. Tensor (with channel normalization) saved to tensor_7ch_131rois_941_S_4036.npz
# Processing Subjects: 100%|█████████▉| 430/431 [2:42:52<00:16, 16.91s/it]2025-11-22 17:38:58,755 - INFO - feature_extraction_manual.py:1563 - DistanceCorr for S 941_S_4187 calculated. Shape: (131, 131). Took 22.75s.
# 2025-11-22 17:38:58,756 - INFO - feature_extraction_manual.py:1480 - Calculating Granger_F_lag1 for S 941_S_4187 (TS shape: (140, 131))...
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# 2025-11-22 17:39:06,705 - INFO - feature_extraction_manual.py:1563 - Granger_F_lag1 for S 941_S_4187 calculated. Shape: (131, 131). Took 7.95s.
# 2025-11-22 17:39:06,706 - INFO - feature_extraction_manual.py:1593 - Connectivity for S 941_S_4187: All 7/7 selected modalities computed successfully.
# 2025-11-22 17:39:06,930 - INFO - feature_extraction_manual.py:1733 - S 941_S_4187: Successfully processed. Tensor (with channel normalization) saved to tensor_7ch_131rois_941_S_4187.npz
# Processing Subjects: 100%|██████████| 431/431 [2:43:08<00:00, 22.71s/it]
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/joblib/externals/loky/backend/resource_tracker.py:359: UserWarning: resource_tracker: There appear to be 213 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/joblib/externals/loky/backend/resource_tracker.py:359: UserWarning: resource_tracker: There appear to be 216 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/joblib/externals/loky/backend/resource_tracker.py:359: UserWarning: resource_tracker: There appear to be 216 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/joblib/externals/loky/backend/resource_tracker.py:359: UserWarning: resource_tracker: There appear to be 216 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/joblib/externals/loky/backend/resource_tracker.py:359: UserWarning: resource_tracker: There appear to be 216 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/diego/anaconda3/envs/serentipia_gpu/lib/python3.10/site-packages/joblib/externals/loky/backend/resource_tracker.py:359: UserWarning: resource_tracker: There appear to be 216 leaked folder objects to clean up at shutdown
#   warnings.warn(
# 2025-11-22 17:44:07,349 - INFO - feature_extraction_manual.py:1910 - Detailed processing log saved to: /home/diego/proyectos/betavae-xai-ad/data/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/pipeline_log_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.csv
# 2025-11-22 17:44:07,355 - INFO - feature_extraction_manual.py:1921 - --- Overall Processing Summary ---
# 2025-11-22 17:44:07,355 - INFO - feature_extraction_manual.py:1922 - Total subjects attempted: 431
# 2025-11-22 17:44:07,356 - INFO - feature_extraction_manual.py:1923 - Successfully processed and individual tensors saved: 431
# 2025-11-22 17:44:07,356 - INFO - feature_extraction_manual.py:1929 - Attempting to assemble global tensor for 431 successfully processed subjects.
# 2025-11-22 17:44:07,356 - WARNING - feature_extraction_manual.py:1937 - Assembling global tensor using np.stack. This may be memory-intensive for large datasets.
# Assembling Global Tensor: 100%|██████████| 431/431 [00:56<00:00,  7.61it/s]
# 2025-11-22 17:45:04,199 - CRITICAL - feature_extraction_manual.py:1960 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 17:45:04,200 - CRITICAL - feature_extraction_manual.py:1961 - !! DATA LEAKAGE ALERT & THESIS BEST PRACTICE: Inter-Channel Normalization of Global Tensor        !!
# 2025-11-22 17:45:04,200 - CRITICAL - feature_extraction_manual.py:1962 - !! La función '_normalize_global_tensor_inter_channel' es un placeholder.                         !!
# 2025-11-22 17:45:04,201 - CRITICAL - feature_extraction_manual.py:1963 - !! Si se implementa para escalar los canales del 'global_conn_tensor' entre sí (ej. Z-score):    !!
# 2025-11-22 17:45:04,201 - CRITICAL - feature_extraction_manual.py:1964 - !!   1. DEBE realizarse DENTRO de cada fold de validación cruzada en el script de MODELADO.      !!
# 2025-11-22 17:45:04,202 - CRITICAL - feature_extraction_manual.py:1965 - !!   2. Los parámetros de normalización (media, std por canal) se calculan ÚNICAMENTE sobre el    !!
# 2025-11-22 17:45:04,202 - CRITICAL - feature_extraction_manual.py:1966 - !!      CONJUNTO DE ENTRENAMIENTO (train_indices) de ESE FOLD.                                        !!
# 2025-11-22 17:45:04,203 - CRITICAL - feature_extraction_manual.py:1967 - !!   3. Estos parámetros (ej. guardados en 'norm_params') se APLICAN de forma fija a los          !!
# 2025-11-22 17:45:04,203 - CRITICAL - feature_extraction_manual.py:1968 - !!      conjuntos de validación y prueba de ESE FOLD.                                             !!
# 2025-11-22 17:45:04,203 - CRITICAL - feature_extraction_manual.py:1969 - !!   4. NO calcular estos parámetros sobre el tensor global completo ANTES de dividir en folds.    !!
# 2025-11-22 17:45:04,204 - CRITICAL - feature_extraction_manual.py:1970 - !!   5. Para la tesis: documentar este procedimiento y considerar mostrar resultados con/sin      !!
# 2025-11-22 17:45:04,204 - CRITICAL - feature_extraction_manual.py:1971 - !!      esta normalización global para demostrar su impacto (y la ausencia de 'peeking').        !!
# 2025-11-22 17:45:04,205 - CRITICAL - feature_extraction_manual.py:1972 - !!      Considerar guardar el hash del split de CV para trazabilidad.                             !!
# 2025-11-22 17:45:04,205 - CRITICAL - feature_extraction_manual.py:1973 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-11-22 17:45:09,182 - INFO - feature_extraction_manual.py:2013 - Global tensor successfully assembled and saved: GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# 2025-11-22 17:45:09,183 - INFO - feature_extraction_manual.py:2014 - Global tensor shape: (431, 7, 131, 131) (Subjects, Channels, ROIs, ROIs)
# 2025-11-22 17:45:09,329 - INFO - feature_extraction_manual.py:2024 - --- fMRI Connectivity Pipeline Finished ---
# 2025-11-22 17:45:09,330 - INFO - feature_extraction_manual.py:2025 - Total execution time: 169.18 minutes.
# 2025-11-22 17:45:09,330 - INFO - feature_extraction_manual.py:2026 - Final main process RAM: 628.84 MB
# 2025-11-22 17:45:09,330 - INFO - feature_extraction_manual.py:2027 - All outputs, logs, and tensors should be in: /home/diego/proyectos/betavae-xai-ad/data/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-11-22 17:45:09,331 - INFO - feature_extraction_manual.py:2028 - TESIS DOCTORAL - RECORDATORIOS CLAVE (Checklist Anti-Leakage & Buenas Prácticas):
# 2025-11-22 17:45:09,331 - INFO - feature_extraction_manual.py:2029 -   1. PREPROCESAMIENTO fMRI PREVIO (CRÍTICO): Documentar exhaustivamente todos los pasos (movimiento, confounds, scrubbing con umbrales FD/DVARS, GSR si aplica, RETROICOR/ICA-AROMA si se usaron). La calidad de estas matrices depende de ello.
# 2025-11-22 17:45:09,331 - INFO - feature_extraction_manual.py:2030 -   2. SELECCIÓN/EXCLUSIÓN DE ROIs Y SUJETOS: Justificar umbral de volumen para ROIs (verificar ROIs clave AD). Justificar criterios de exclusión de sujetos (ej. % outliers, FD medio); asegurar que no introducen sesgo de grupo.
# 2025-11-22 17:45:09,331 - INFO - feature_extraction_manual.py:2031 -   3. VARIABILIDAD HRF: Documentar uso de HRF canónica y considerar discusión de sus limitaciones/alternativas (HRF por sujeto, TDM).
# 2025-11-22 17:45:09,332 - INFO - feature_extraction_manual.py:2032 -   4. PARCELACIÓN: Documentar AAL3. Considerar discutir alternativas (multi-escala, híbrida, ej. Schaefer+Yeo, o parcelaciones específicas para AD) para trabajos futuros.
# 2025-11-22 17:45:09,332 - INFO - feature_extraction_manual.py:2033 -   5. REORDENAMIENTO DE ROIs (MUY RECOMENDADO PARA CNNs): Si se implementa, detallar el mapeo a redes funcionales (Yeo-17, gradientes de conectividad) y el nuevo orden. Guardar esta información.
# 2025-11-22 17:45:09,332 - INFO - feature_extraction_manual.py:2034 -   6. NORMALIZACIÓN DE MATRICES:
# 2025-11-22 17:45:09,332 - INFO - feature_extraction_manual.py:2035 -      a. Intra-Canal/Sujeto: RobustScaler (off-diagonal) (implementado) - documentar.
# 2025-11-22 17:45:09,332 - INFO - feature_extraction_manual.py:2036 -      b. Inter-Canal Global: DEBE realizarse DENTRO de los folds de CV en el script de modelado (parámetros del set de entrenamiento aplicados a validación/test) para evitar data leakage. Documentar método (ej. Z-score) y este procedimiento. Considerar guardar hash del split de CV para trazabilidad.
# 2025-11-22 17:45:09,333 - INFO - feature_extraction_manual.py:2037 -   7. SELECCIÓN DE CANALES DE CONECTIVIDAD: Justificar elección inicial. Planificar y documentar análisis de ablación, gating o importancia de características (SHAP, mapas de sensibilidad) para evaluar la contribución de cada canal (especialmente MI y Granger) en el modelo VAE final y decidir sobre su retención.
# 2025-11-22 17:45:09,333 - INFO - feature_extraction_manual.py:2038 -      (Sugerencia práctica: empezar con Pearson-Full, añadir OMST, dFC-StdDev; evaluar MI y Granger con cautela).
# 2025-11-22 17:45:09,333 - INFO - feature_extraction_manual.py:2039 -      (Considerar añadir métricas como Graphical Lasso/Correlación Parcial, Edge-Time-Series, o HMM/CAPs si el tiempo lo permite y se justifica).
# 2025-11-22 17:45:09,333 - INFO - feature_extraction_manual.py:2040 -   8. INTERPRETACIÓN DE MEDIDAS: Ser cauto con la interpretación de Granger. Correlacionar hallazgos de dFC con clínica si es posible. Usar técnicas de decodificación (connectivity gradient decoding, BrainMap) para interpretar factores latentes del VAE.
# 2025-11-22 17:45:09,334 - INFO - feature_extraction_manual.py:2041 -   9. VALIDACIÓN DEL MODELO VAE Y CLASIFICADOR: Describir la arquitectura del VAE (considerar GNN/VAE híbrido), función de pérdida (ej. β-VAE, aprendizaje contrastivo), y la estrategia de validación cruzada ANIDADA para el clasificador final, asegurando que no haya data leakage en ningún paso (incluida la optimización de hiperparámetros con Optuna/W&B en el bucle interno).
# 2025-11-22 17:45:09,334 - INFO - feature_extraction_manual.py:2042 -  10. CONFIABILIDAD Y ESTADÍSTICA: Si hay datos test-retest, calcular ICC de las matrices/canales (descartar canales con ICC < ~0.4). Para comparaciones de grupo o mapas de importancia, usar métodos estadísticos robustos (NBS, TFCE, spin-tests).
# 2025-11-22 17:45:09,334 - INFO - feature_extraction_manual.py:2043 -  11. HARMONIZACIÓN MULTI-SITIO (Sugerencia Tesis 7): Si los datos provienen de múltiples sitios/escáneres, aplicar harmonización (ej. ComBat, neuroHarmonize) sobre las características derivadas DENTRO de los folds de CV (parámetros del set de entrenamiento).
# 2025-11-22 17:45:09,334 - INFO - feature_extraction_manual.py:2044 -  12. DIMENSIONALIDAD: Reconocer que se aumenta la dimensionalidad de las features, no el N. Mitigar con regularización en el VAE (β alto, dropout de canal, gating, etc.) y early stopping basado en métricas de validación (AUROC, no solo reconstrucción). Considerar data augmentation (random masking de ROIs/canales).
# 2025-11-22 17:45:09,334 - INFO - feature_extraction_manual.py:2045 -  13. REPRODUCIBILIDAD (Sugerencia Tesis 10): Exportar resultados en formato BIDS-Derivatives si es posible. Publicar código (ej. Zenodo con DOI) y describir detalladamente el pipeline (versión v6.5.17).
# 2025-11-22 17:45:09,335 - INFO - feature_extraction_manual.py:2046 -  14. CITAS: Citar dyconnmap si se usó OMST, y todas las herramientas/paquetes relevantes.

# %%
import numpy as np
from pathlib import Path

output_dir = fem.BASE_PATH_AAL3 / fem.OUTPUT_CONNECTIVITY_DIR_NAME
global_npz_path = next(output_dir.glob("GLOBAL_TENSOR_from_*.npz"))
print("GLOBAL_TENSOR path:", global_npz_path)

with np.load(global_npz_path) as data:
    G = data["global_tensor_data"]     # (N_subjects, N_channels, 131, 131)
    subs = data["subject_ids"]
    chans = data["channel_names"]
    roi_order_name = data["roi_order_name"]
    roi_names = data["roi_names_in_order"]
    net_labels = data["network_labels_in_order"]

print("GLOBAL_TENSOR shape:", G.shape)
print("Canales:", chans)
print("ROI order name:", roi_order_name)
print("Primeras 10 ROIs en orden global:")
for i in range(10):
    print(f"{i:3d} {roi_names[i]:25s} → {net_labels[i]}")
# Out:
# GLOBAL_TENSOR path: /home/diego/proyectos/betavae-xai-ad/data/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# GLOBAL_TENSOR shape: (431, 7, 131, 131)
# Canales: ['Pearson_OMST_GCE_Signed_Weighted' 'Pearson_Full_FisherZ_Signed'
#  'MI_KNN_Symmetric' 'dFC_AbsDiffMean' 'dFC_StdDev' 'DistanceCorr'
#  'Granger_F_lag1']
# ROI order name: aal3_manual_yeo17_order
# Primeras 10 ROIs en orden global:
#   0 Cuneus_L                  → Visual_Peripheral
#   1 Fusiform_L                → Visual_Peripheral
#   2 Lingual_L                 → Visual_Peripheral
#   3 Occipital_Inf_L           → Visual_Peripheral
#   4 Occipital_Sup_L           → Visual_Peripheral
#   5 Cuneus_R                  → Visual_Peripheral
#   6 Fusiform_R                → Visual_Peripheral
#   7 Lingual_R                 → Visual_Peripheral
#   8 Occipital_Inf_R           → Visual_Peripheral
#   9 Occipital_Sup_R           → Visual_Peripheral
